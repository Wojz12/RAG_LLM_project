# %% [markdown]
# <a href="https://colab.research.google.com/github/Wojz12/RAG_LLM_project/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b new_cursor_local https://github.com/Wojz12/RAG_LLM_project.git
# Out:
# Cloning into 'RAG_LLM_project'...
# remote: Enumerating objects: 108, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 108 (delta 51), reused 78 (delta 38), pack-reused 0 (from 0)
# Receiving objects: 100% (108/108), 11.49 MiB | 26.93 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %%
# %cd RAG_LLM_project
# Out:
# /content/RAG_LLM_project/RAG_LLM_project

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached bitsandbytes-0.48.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# ...
#   Using cached rank_bm25-0.2.2-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached faiss_cpu-1.13.0-cp39-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (7.7 kB)
# ...
# Using cached bitsandbytes-0.48.2-py3-none-manylinux_2_24_x86_64.whl (59.4 MB)
# Using cached rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Using cached faiss_cpu-1.13.0-cp39-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (23.6 MB)
# ...

# %%
import os
# Dodajemy obecny folder do ścieżki Pythona, żeby widział moduł 'src'
os.environ['PYTHONPATH'] = os.getcwd()

# Uruchomienie pipeline'u
# Używamy sample_size np. 5000, żeby szybko zbudować indeks w Colabie (bo nie przesyłamy pliku .pkl)
# !python src/main.py \
    --retriever_type dense \
    --query "Where in England was Dame Judi Dench born?" \
    --sample_size 5000 \
    --force_rebuild
# Out:
# 2025-11-23 00:05:35.185795: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763856335.204947    1268 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763856335.210791    1268 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763856335.225510    1268 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python src/pipeline.py --mode generate --query "Who wrote the novel '1984'?"
# Out:
# 2025-11-23 00:16:10.511829: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763856970.531551    4101 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763856970.537466    4101 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763856970.552672    4101 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# Pytanie 1: O Orwella
# Dodałem tutaj: --retriever_type dense
# !python src/pipeline.py --mode generate  --query "Who wrote the novel '1984'?"

# Pytanie 2: O Olimpiadę
# Dodałem tutaj: --retriever_type dense
# !python src/pipeline.py --mode generate  --query "Which country hosted the 2016 Summer Olympics?"
# Out:
# 2025-11-23 00:25:48.730768: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763857548.750562    6558 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763857548.756590    6558 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763857548.772586    6558 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python src/pipeline.py --mode generate  --query "In which country did he widespread use of ISDN begin in 1988?"
# Out:
# 2025-11-23 00:28:32.582878: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763857712.602456    7268 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763857712.608413    7268 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763857712.623633    7268 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python src/pipeline.py --mode generate  --query "Which was the first European country to abolish capital punishment?"
# Out:
# 2025-11-23 00:30:23.667761: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763857823.687541    7735 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763857823.693631    7735 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1763857823.708848    7735 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
